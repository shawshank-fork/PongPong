# %% [markdown]
# ## Question `1

# %%
a = 10
b = 5
c = "Hello"
d = True

print(a,b,c,d)

print(type(a), type(b),type(c), type(d))

del c

print(a, b, d)
# Out:
# 10 5 Hello True
# <class 'int'> <class 'int'> <class 'str'> <class 'bool'>
# 10 5 True

# %% [markdown]
# ## Question 2

# %%
num = int(input("enter a 3 digit number:"))

rev = (num % 10) * 100 + (num // 10 % 10) * 10 + (num // 100)
print("reverse = ", rev)
# Out:
# reverse =  211

# %% [markdown]
# ## Question 3

# %%
first = input("first name: ")
last = input("last name: ")

print(last + " " + first)
# Out:
# lakhaiyar shashank

# %% [markdown]
# ## Question 4

# %%
x = 20
y = 7

print("mem loc of x = ", id(x))
print("mem loc of y = ", id(y))
print("Floating div:", x/y )
print("int div:", x//y)
# Out:
# mem loc of x =  140731713041928
# mem loc of y =  140731713041512
# Floating div: 2.857142857142857
# int div: 2

# %% [markdown]
# ## Question 6

# %%
a = int(input("enter value of a:"))
b = int(input("ente value of b:"))

a = a + b
b = a - b
a = a - b

print("after swapping: a=", a, ", b = ",b)
# Out:
# after swapping: a= 4 , b =  5

# %% [markdown]
# ## Question 5

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Largest number is:", (a > b) * a + (b > a) * b)
# Out:
# Largest number is: 6

# %% [markdown]
# ## Question 7

# %%
s = {1,2,3,4,5}
x = int(input("enter number to check: "))

print(x in s)
# Out:
# True

# %% [markdown]
# ## Question 8

# %%
a = int(input("side a: "))
b = int(input("side b: "))
c = int(input("side c: "))

print(1 if (a+b > c and b+c > a and c+a > b) else 0)
# Out:
# 0

# %% [markdown]
# ## Question 9

# %%
x1, y1 = map(float, input("enter x1 y1: ").split())
x2, y2 = map(float, input("enter x2,y2:").split())

dist = ((x2-x1)**2 + (y2-y1)**2)** 0.5
print("dis:", dist)
# Out:
# dis: 1.4142135623730951

# %% [markdown]
# ## Question 10

# %%
num = input("enter 3 didigt num: ")
print("palindrome" if num == num[::-1] else "not palindrmome")
# Out:
# not palindrmome

# %% [markdown]
# ## Question 11

# %%
ch = input("enter aplhabet : ")
print(ch.upper() if ch.islower() else ch.lower())
# Out:
# ASJID

# %% [markdown]
# ## Question 12

# %%
n = int(input("Enter number of terms: "))

a, b = 0, 1
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# 0 1 1 2

# %% [markdown]
# ## Question 13

# %%
num = int(input("Enter number: "))
i = 2
factors = set()

while num > 1:
    if num % i == 0:
        factors.add(i)
        num //= i
    else:
        i += 1

print("Prime Factors:", factors)
# Out:
# Prime Factors: {2, 3}

# %% [markdown]
# ## Question 14

# %%
num = int(input("Enter decimal number: "))

print("1. Binary\n2. Octal\n3. Hexadecimal")
choice = int(input("Enter choice: "))

match choice:
    case 1: print(bin(num))
    case 2: print(oct(num))
    case 3: print(hex(num))
    case _: print("Invalid choice")
# Out:
# 1. Binary
# 2. Octal
# 3. Hexadecimal
# 0o14

# %% [markdown]
# ## Question 15

# %%
import random

sec = random.randint(1,20)
guess = 0

while guess != sec:
    guess = int(input("guess number: "))
    if guess > sec:
        print("too hight")
    elif guess < sec:
        print("too low")
    else:
        print("correct")
# Out:
# too hight
# too low
# correct

# %% [markdown]
# ## Question 16

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows + 1):
    print(" " * (rows - i) + "*" * (2*i - 1))
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
